# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Values Count

# %%
#value count (use for series and dataframe)
marks = pd.DataFrame([
    [23,34,43],[41,54,93],[89,85,42],[89,43,53]
],columns=['IQ','Marks','Pakages'])
marks
# Out:
#    IQ  Marks  Pakages
# 0  23     34       43
# 1  41     54       93
# 2  89     85       42
# 3  89     43       53

# %%
marks.value_counts()    #tell the data frequence
# Out:
# IQ  Marks  Pakages
# 23  34     43         1
# 41  54     93         1
# 89  43     53         1
#     85     42         1
# Name: count, dtype: int64

# %%
pd_series = pd.Series([32,43,123,53,43])
pd_series.value_counts()
# Out:
# 43     2
# 32     1
# 123    1
# 53     1
# Name: count, dtype: int64

# %%
#find which player has won most pots -> in finals and qualifiers
ipl = pd.read_csv('/content/ipl-matches.csv')
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()>1
# Out:
# Player_of_Match
# F du Plessis          True
# SK Raina              True
# KA Pollard            True
# JJ Bumrah             True
# AB de Villiers        True
# MK Pandey             True
# M Vijay               True
# A Kumble              True
# YK Pathan             True
# SR Watson             True
# HH Pandya            False
# RM Patidar           False
# JC Buttler           False
# RR Pant              False
# KS Williamson        False
# MP Stoinis           False
# TA Boult             False
# SP Narine            False
# RD Gaikwad           False
# VR Iyer              False
# DA Miller            False
# Washington Sundar    False
# NM Coulter-Nile      False
# KV Sharma            False
# BCJ Cutting          False
# KH Pandya            False
# SA Yadav             False
# Rashid Khan          False
# AD Russell           False
# RG Sharma            False
# A Nehra              False
# DA Warner            False
# MC Henriques         False
# ...

# %%
#toss Decision plot
ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#how many matches each team has played
(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %% [markdown]
# # Sort_Values

# %%
#sort_values  (series and dataframe)
pd.Series([23,94,89,75,94,95]).sort_values(ascending=False)
# Out:
# 5    95
# 1    94
# 4    94
# 2    89
# 3    75
# 0    23
# dtype: int64

# %%
movies = pd.read_csv('movies.csv')
movies.sort_values('title_x')
# Out:
#                        title_x    imdb_id  \
# 1498        16 December (film)  tt0313844
# 1021               1920 (film)  tt1301698
# 287               1920: London  tt5638500
# 723     1920: The Evil Returns  tt2222550
# 1039          1971 (2007 film)  tt0983990
# ...                        ...        ...
# 778   Zindagi Na Milegi Dobara  tt1562872
# 670          Zindagi Tere Naam  tt2164702
# 756                   Zokkomon  tt1605790
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 1623                  Zubeidaa  tt0255713
#
#                                             poster_path  \
# 1498  https://upload.wikimedia.org/wikipedia/en/thum...
# 1021  https://upload.wikimedia.org/wikipedia/en/thum...
# 287   https://upload.wikimedia.org/wikipedia/en/thum...
# 723   https://upload.wikimedia.org/wikipedia/en/e/e7...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
students = pd.DataFrame(
    {
        'name':['nitish','ankit','rupesh',np.nan,'mrityunjay',np.nan,'rishabh',np.nan,'aditya',np.nan],
        'college':['bit','iit','vit',np.nan,np.nan,'vlsi','ssit',np.nan,np.nan,'git'],
        'branch':['eee','it','cse',np.nan,'me','ce','civ','cse','bio',np.nan],
        'cgpa':[6.66,8.25,6.41,np.nan,5.6,9.0,7.4,10,7.4,np.nan],
        'package':[4,5,6,np.nan,6,7,8,9,np.nan,np.nan]
    }
)
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
# in which value have the nan (null) values we can use this line of code
students.sort_values('name',na_position='first',ascending = False, inplace = True)

# %%
students
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 2      rupesh     vit    cse   6.41      6.0
# 6     rishabh    ssit    civ   7.40      8.0
# 0      nitish     bit    eee   6.66      4.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 1       ankit     iit     it   8.25      5.0
# 8      aditya     NaN    bio   7.40      NaN

# %%
#how you sort the multi_series
movies.sort_values(['year_of_release','title_x'],ascending=(True,False)).head(50)
# Out:
#                                 title_x    imdb_id  \
# 1623                           Zubeidaa  tt0255713
# 1625               Yeh Zindagi Ka Safar  tt0298607
# 1622      Yeh Teraa Ghar Yeh Meraa Ghar  tt0298606
# 1620           Yeh Raaste Hain Pyaar Ke  tt0292740
# 1573                Yaadein (2001 film)  tt0248617
# 1621                            Tum Bin  tt0290326
# 1624              Tera Mera Saath Rahen  tt0301250
# 1615                  Style (2001 film)  tt0306855
# 1616          Rehnaa Hai Terre Dil Mein  tt0299108
# 1618                       Rahul (film)  tt0277981
# 1619                  Pyaar Zindagi Hai  tt0847758
# 1612                Pyaar Tune Kya Kiya  tt0281102
# 1611            Pyaar Ishq Aur Mohabbat  tt0285958
# 1613                          Paagalpan  tt0285319
# 1608                         One 2 Ka 4  tt0227194
# 1617                Officer (2001 film)  tt0265452
# 1607            Nayak (2001 Hindi film)  tt0291376
# ...

# %%
#Rank       -> (Series)
batsman = pd.read_csv('/content/batsman_runs_ipl.csv')
batsman['Batting_rank'] = batsman['batsman_run'].rank(ascending=False)
batsman.sort_values('Batting_rank').head()
# Out:
#         batter  batsman_run  Batting_rank
# 569    V Kohli         6634           1.0
# 462   S Dhawan         6244           2.0
# 130  DA Warner         5883           3.0
# 430  RG Sharma         5881           4.0
# 493   SK Raina         5536           5.0

# %%
# Sort_index    (series and database)
marks = {
    'Marks':42,
    'English':34,
    'Science':89,
    'Punjabi':85
}
marks_series = pd.Series(marks)
marks_series
# Out:
# Marks      42
# English    34
# Science    89
# Punjabi    85
# dtype: int64

# %%
marks_series.sort_index(ascending=False)
# Out:
# Science    89
# Punjabi    85
# Marks      42
# English    34
# dtype: int64

# %%
#set_index  (dataframe) -> inplace
batsman.set_index('batter',inplace=True)
batsman
# Out:
#                 batsman_run  Batting_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %%
#reset index (series and dataframes both )  -->drop parameter
batsman.reset_index()
# Out:
#              batter  batsman_run  Batting_rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
#how to replace the existing index without loosing
batsman.reset_index().set_index('Batting_rank') # in this way we did not lose the batter series and first convert into normal and than set the index
# Out:
#                       batter  batsman_run
# Batting_rank
# 166.5         A Ashish Reddy          280
# 226.0               A Badoni          161
# 535.0             A Chandila            4
# 329.0               A Chopra           53
# 402.5            A Choudhary           25
# ...                      ...          ...
# 594.0             Yash Dayal            0
# 343.0          Yashpal Singh           47
# 547.5            Younis Khan            3
# 27.0            Yuvraj Singh         2754
# 256.0                 Z Khan          117
#
# [605 rows x 2 columns]

# %%
# series to dataframe using reset_index
marks_series.reset_index()
# Out:
#      index   0
# 0    Marks  42
# 1  English  34
# 2  Science  89
# 3  Punjabi  85

# %% [markdown]
# #rename (Dataframe) -> index

# %%
movies.set_index('title_x',inplace=True)

# %%
movies.rename(columns={'imdb_id':'ID','poster_path':'Directory'})
# Out:
#                                    title_x          ID  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                               Directory  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# how to change  the index name
movies.rename(index={'Uri: The Surgical Strike':'KGF2'})
# Out:
#                                          imdb_id  \
# title_x
# KGF2                                   tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                             poster_path  \
# title_x
# KGF2                                  https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# unique (Series) #extract the all unique values
temp = pd.Series([1,1,3,4,5,43,23,3,2,2,5,3,4,3,3,1,np.nan,np.nan,np.nan])
len(temp.unique()) # count the messing values
#total 8 uniqe values
# Out:
# 8

# %%
#nuniqe(series + dataframe)  -> does not count nan - > dropna paramater
ipl['Season'].nunique() # short head
# Out:
# 15

# %% [markdown]
# # isnull run on the both series and dataframe

# %%
#innull (Series and dataframe)
len(students['name'][students['name'].isnull()])
# Out:
# 4

# %%
#notnull (series and dataframe)
students['name'][students['name'].notnull()] # instead of these in name columns all values are null
# Out:
# 2        rupesh
# 6       rishabh
# 0        nitish
# 4    mrityunjay
# 1         ankit
# 8        aditya
# Name: name, dtype: object

# %%
#hasname(series)
students['name'].hasnans
# Out:
# True

# %%
#lets run on the dataframe isnull,notnullnhasnans

# %%
students.isnull()
# Out:
#     name  college  branch   cgpa  package
# 3   True     True    True   True     True
# 5   True    False   False  False    False
# 7   True     True   False  False    False
# 9   True    False    True   True     True
# 2  False    False   False  False    False
# 6  False    False   False  False    False
# 0  False    False   False  False    False
# 4  False     True   False  False    False
# 1  False    False   False  False    False
# 8  False     True   False  False     True

# %%
ipl.notnull()
# Out:
#        ID  City  Date  Season  MatchNumber  Team1  Team2  Venue  TossWinner  \
# 0    True  True  True    True         True   True   True   True        True
# 1    True  True  True    True         True   True   True   True        True
# 2    True  True  True    True         True   True   True   True        True
# 3    True  True  True    True         True   True   True   True        True
# 4    True  True  True    True         True   True   True   True        True
# ..    ...   ...   ...     ...          ...    ...    ...    ...         ...
# 945  True  True  True    True         True   True   True   True        True
# 946  True  True  True    True         True   True   True   True        True
# 947  True  True  True    True         True   True   True   True        True
# 948  True  True  True    True         True   True   True   True        True
# 949  True  True  True    True         True   True   True   True        True
#
# ...

# %% [markdown]
# Now, we find the null value.let's, remove it completely or filling it

# %%
students
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 2      rupesh     vit    cse   6.41      6.0
# 6     rishabh    ssit    civ   7.40      8.0
# 0      nitish     bit    eee   6.66      4.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 1       ankit     iit     it   8.25      5.0
# 8      aditya     NaN    bio   7.40      NaN

# %%
#dropna (series and dataframe) -> how parameter -> works like or
students['name'].dropna()
# Out:
# 2        rupesh
# 6       rishabh
# 0        nitish
# 4    mrityunjay
# 1         ankit
# 8        aditya
# Name: name, dtype: object

# %%
#apply on series
students.dropna(how='any')
# Out:
#       name college branch  cgpa  package
# 2   rupesh     vit    cse  6.41      6.0
# 6  rishabh    ssit    civ  7.40      8.0
# 0   nitish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0

# %%
# with dropna only remove the row that have all the messing values
students.dropna(how='all')
# Out:
#          name college branch   cgpa  package
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 2      rupesh     vit    cse   6.41      6.0
# 6     rishabh    ssit    civ   7.40      8.0
# 0      nitish     bit    eee   6.66      4.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 1       ankit     iit     it   8.25      5.0
# 8      aditya     NaN    bio   7.40      NaN

# %%
#remove the values on the column base
students.dropna(subset=['name'])
#two column bases
students.dropna(subset=['name','package'])
# Out:
#          name college branch  cgpa  package
# 2      rupesh     vit    cse  6.41      6.0
# 6     rishabh    ssit    civ  7.40      8.0
# 0      nitish     bit    eee  6.66      4.0
# 4  mrityunjay     NaN     me  5.60      6.0
# 1       ankit     iit     it  8.25      5.0

# %%
#fillna(series and dataframe)
students['name'].fillna('unkonw')
# Out:
# 3        unkonw
# 5        unkonw
# 7        unkonw
# 9        unkonw
# 2        rupesh
# 6       rishabh
# 0        nitish
# 4    mrityunjay
# 1         ankit
# 8        aditya
# Name: name, dtype: object

# %%
students.fillna(':_:')
# Out:
#          name college branch  cgpa package
# 3         :_:     :_:    :_:   :_:     :_:
# 5         :_:    vlsi     ce   9.0     7.0
# 7         :_:     :_:    cse  10.0     9.0
# 9         :_:     git    :_:   :_:     :_:
# 2      rupesh     vit    cse  6.41     6.0
# 6     rishabh    ssit    civ   7.4     8.0
# 0      nitish     bit    eee  6.66     4.0
# 4  mrityunjay     :_:     me   5.6     6.0
# 1       ankit     iit     it  8.25     5.0
# 8      aditya     :_:    bio   7.4     :_:

# %%
# always handle with the columns base and now fill with the average
students['package'].fillna(students['package'].mean())
# Out:
# 3    6.428571
# 5    7.000000
# 7    9.000000
# 9    6.428571
# 2    6.000000
# 6    8.000000
# 0    4.000000
# 4    6.000000
# 1    5.000000
# 8    6.428571
# Name: package, dtype: float64

# %%
# fill with different ways
students['name'].bfill()  # replace with forward fill use ffill
# Out:
# 3        rupesh
# 5        rupesh
# 7        rupesh
# 9        rupesh
# 2        rupesh
# 6       rishabh
# 0        nitish
# 4    mrityunjay
# 1         ankit
# 8        aditya
# Name: name, dtype: object

# %%
# drop duplicates(series + dataframe)
movies.duplicated()
# Out:
# title_x
# Uri: The Surgical Strike                False
# Battalion 609                           False
# The Accidental Prime Minister (film)    False
# Why Cheat India                         False
# Evening Shadows                         False
#                                         ...
# Tera Mera Saath Rahen                   False
# Yeh Zindagi Ka Safar                    False
# Sabse Bada Sukh                         False
# Daaka                                   False
# Humsafar                                False
# Length: 1629, dtype: bool

# %%
# drop duplicate
temp_Data = pd.Series([1,1,3,32,4,4])
temp_Data.drop_duplicates()
# Out:
# 0     1
# 2     3
# 3    32
# 4     4
# dtype: int64

# %%
students.drop_duplicates(keep='first')    #last
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 2      rupesh     vit    cse   6.41      6.0
# 6     rishabh    ssit    civ   7.40      8.0
# 0      nitish     bit    eee   6.66      4.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 1       ankit     iit     it   8.25      5.0
# 8      aditya     NaN    bio   7.40      NaN

# %%
#find the last match played by virat kohil in dehli
ipl= pd.read_csv('/content/ipl-matches.csv')

# %%
ipl['new_playes'] = ipl['Team1Players'] + ipl['Team2Players']
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field  ...
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field  ...
# ...

# %%
#create the demo funcation

def find_kohli(list_players):
  return 'V Kohli' in list_players

# %%
# now apply the ipl dataframe
ipl['now_see'] = ipl['new_playes'].apply(find_kholi)
ipl[(ipl['City'] == 'Delhi')  & (ipl['now_see'] == True)].drop_duplicates(subset=['City','now_see'],keep='first')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3537/3158647126.py in <cell line: 0>()
#       1 # now apply the ipl dataframe
# ----> 2 ipl['now_see'] = ipl['new_playes'].apply(find_kholi)
#       3 ipl[(ipl['City'] == 'Delhi')  & (ipl['now_see'] == True)].drop_duplicates(subset=['City','now_see'],keep='first')
#
# NameError: name 'find_kholi' is not defined

# %%
ipl.loc[208]
# Out:
# ID                                                           1178421
# City                                                           Delhi
# Date                                                      2019-04-28
# Season                                                          2019
# MatchNumber                                                       46
# Team1                                                 Delhi Capitals
# Team2                                    Royal Challengers Bangalore
# Venue                                           Arun Jaitley Stadium
# TossWinner                                            Delhi Capitals
# TossDecision                                                     bat
# SuperOver                                                          N
# WinningTeam                                           Delhi Capitals
# WonBy                                                           Runs
# Margin                                                          16.0
# ...

# %% [markdown]
# drop (series and dataframe)

# %%
#drop
temp = pd.Series([10,4,2,5,2,3,5,3,2])
temp
# Out:
# 0    10
# 1     4
# 2     2
# 3     5
# 4     2
# 5     3
# 6     5
# 7     3
# 8     2
# dtype: int64

# %%
temp.drop(index=[0,8,7,5,6])
# Out:
# 1    4
# 2    2
# 3    5
# 4    2
# dtype: int64

# %%
students
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 2      rupesh     vit    cse   6.41      6.0
# 6     rishabh    ssit    civ   7.40      8.0
# 0      nitish     bit    eee   6.66      4.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 1       ankit     iit     it   8.25      5.0
# 8      aditya     NaN    bio   7.40      NaN

# %%
students.drop(columns=['branch','cgpa'])
# Out:
#          name college  package
# 3         NaN     NaN      NaN
# 5         NaN    vlsi      7.0
# 7         NaN     NaN      9.0
# 9         NaN     git      NaN
# 2      rupesh     vit      6.0
# 6     rishabh    ssit      8.0
# 0      nitish     bit      4.0
# 4  mrityunjay     NaN      6.0
# 1       ankit     iit      5.0
# 8      aditya     NaN      NaN

# %%
#with index number
students.drop(index=[9,7,5,3])
# Out:
#          name college branch  cgpa  package
# 2      rupesh     vit    cse  6.41      6.0
# 6     rishabh    ssit    civ  7.40      8.0
# 0      nitish     bit    eee  6.66      4.0
# 4  mrityunjay     NaN     me  5.60      6.0
# 1       ankit     iit     it  8.25      5.0
# 8      aditya     NaN    bio  7.40      NaN

# %%
students.set_index('name').drop(index=['ankit','rupesh'])
# Out:
#            college branch   cgpa  package
# name
# NaN            NaN    NaN    NaN      NaN
# NaN           vlsi     ce   9.00      7.0
# NaN            NaN    cse  10.00      9.0
# NaN            git    NaN    NaN      NaN
# rishabh       ssit    civ   7.40      8.0
# nitish         bit    eee   6.66      4.0
# mrityunjay     NaN     me   5.60      6.0
# aditya         NaN    bio   7.40      NaN

# %% [markdown]
# #apply (series and dataframe)

# %%
#apply with series
temp = pd.Series([12,20,34,554,54])
temp
# Out:
# 0     12
# 1     20
# 2     34
# 3    554
# 4     54
# dtype: int64

# %%
def sigmoid(value):
  return 1/1+np.exp(-value)

# %%
temp.apply(sigmoid)
# Out:
# 0    1.000006
# 1    1.000000
# 2    1.000000
# 3    1.000000
# 4    1.000000
# dtype: float64

# %%
#apply with dataframe
points_df = pd.DataFrame(
    {
        '1st point':[(3,4),(-6,5),(0,0),(-10,1),(4,5)],
        '2nd point':[(-3,4),(0,0),(2,2),(10,10),(1,1)]
    }
)

points_df
# Out:
#   1st point 2nd point
# 0    (3, 4)   (-3, 4)
# 1   (-6, 5)    (0, 0)
# 2    (0, 0)    (2, 2)
# 3  (-10, 1)  (10, 10)
# 4    (4, 5)    (1, 1)

# %%
def euclidean(row):
  pt_A = row['1st point']
  pt_B = row['2nd point']
  return ((pt_A[0] - pt_B[0])**2 + (pt_A[1] - pt_B[1])**2)**0.5

# %%
points_df['distence'] = points_df.apply(euclidean,axis = 1)
points_df
# Out:
#   1st point 2nd point   distence
# 0    (3, 4)   (-3, 4)   6.000000
# 1   (-6, 5)    (0, 0)   7.810250
# 2    (0, 0)    (2, 2)   2.828427
# 3  (-10, 1)  (10, 10)  21.931712
# 4    (4, 5)    (1, 1)   5.000000
